# %%
import os
import cv2
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Bidirectional, LSTM, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Reshape
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import load_img, img_to_array
print("Done")
# Out:
# Done

# %%
# Dataset path and parameters
dataset_path = '/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone'
img_size = 150
batch_size = 64
classes = ['Normal', 'Cyst', 'Tumor', 'Stone']

# Load and preprocess the dataset
def load_data(dataset_path, classes):
    data = []
    labels = []
    for i, class_name in enumerate(classes):
        class_path = os.path.join(dataset_path, class_name)
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            try:
                img = cv2.imread(img_path)
                img = cv2.resize(img, (img_size, img_size))
                data.append(img)
                labels.append(i)
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")
    return np.array(data), np.array(labels)

data, labels = load_data(dataset_path, classes)

# %%
# Normalize and one-hot encode
data = data / 255.0
labels = to_categorical(labels, num_classes=len(classes))
#labels

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# CNN with BiLSTM model
input_layer = Input(shape=(img_size, img_size, 3))

# CNN Layers
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = GlobalAveragePooling2D()(x)  # Convert feature maps to 1D vector

# Reshape for BiLSTM
x = Reshape((1, -1))(x)  # Reshape to (batch_size, timesteps=1, features)

# BiLSTM Layer
x = Bidirectional(LSTM(128, return_sequences=False))(x)

# Fully Connected Layers
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output_layer = Dense(len(classes), activation='softmax')(x)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
from tensorflow.keras.optimizers import SGD

model.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=batch_size,
    epochs=80,
    verbose=1
)
# Out:
# Epoch 1/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.4058 - loss: 1.3632 - val_accuracy: 0.4154 - val_loss: 1.3198
# Epoch 2/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.4152 - loss: 1.3100 - val_accuracy: 0.4154 - val_loss: 1.2955
# Epoch 3/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4074 - loss: 1.2926 - val_accuracy: 0.4154 - val_loss: 1.2862
# Epoch 4/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.3958 - loss: 1.2912 - val_accuracy: 0.4154 - val_loss: 1.2821
# Epoch 5/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.4102 - loss: 1.2740 - val_accuracy: 0.4154 - val_loss: 1.2799
# Epoch 6/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4065 - loss: 1.2795 - val_accuracy: 0.4154 - val_loss: 1.2781
# Epoch 7/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4176 - loss: 1.2655 - val_accuracy: 0.4154 - val_loss: 1.2756
# Epoch 8/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4196 - loss: 1.2612 - val_accuracy: 0.4154 - val_loss: 1.2723
# Epoch 9/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4089 - loss: 1.2681 - val_accuracy: 0.4154 - val_loss: 1.2671
# Epoch 10/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4144 - loss: 1.2585 - val_accuracy: 0.4154 - val_loss: 1.2605
# Epoch 11/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.3969 - loss: 1.2599 - val_accuracy: 0.4154 - val_loss: 1.2506
# Epoch 12/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4087 - loss: 1.2470 - val_accuracy: 0.4208 - val_loss: 1.2395
# Epoch 13/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4325 - loss: 1.2374 - val_accuracy: 0.4721 - val_loss: 1.2279
# Epoch 14/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.4685 - loss: 1.2361 - val_accuracy: 0.5069 - val_loss: 1.2129
# Epoch 15/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.5196 - loss: 1.2082 - val_accuracy: 0.5417 - val_loss: 1.1989
# Epoch 16/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.5290 - loss: 1.1954 - val_accuracy: 0.5489 - val_loss: 1.1841
# Epoch 17/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.5411 - loss: 1.1805 - val_accuracy: 0.5547 - val_loss: 1.1716
# Epoch 18/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5515 - loss: 1.1650 - val_accuracy: 0.5453 - val_loss: 1.1624
# Epoch 19/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5446 - loss: 1.1574 - val_accuracy: 0.5506 - val_loss: 1.1495
# Epoch 20/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5495 - loss: 1.1451 - val_accuracy: 0.5515 - val_loss: 1.1413
# Epoch 21/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5517 - loss: 1.1380 - val_accuracy: 0.5498 - val_loss: 1.1360
# Epoch 22/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5393 - loss: 1.1425 - val_accuracy: 0.5529 - val_loss: 1.1284
# Epoch 23/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5384 - loss: 1.1359 - val_accuracy: 0.5466 - val_loss: 1.1243
# Epoch 24/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5500 - loss: 1.1175 - val_accuracy: 0.5524 - val_loss: 1.1164
# Epoch 25/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5570 - loss: 1.1075 - val_accuracy: 0.5551 - val_loss: 1.1094
# Epoch 26/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5726 - loss: 1.0805 - val_accuracy: 0.5618 - val_loss: 1.1017
# Epoch 27/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5618 - loss: 1.0899 - val_accuracy: 0.5685 - val_loss: 1.0937
# Epoch 28/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.5642 - loss: 1.0952 - val_accuracy: 0.5734 - val_loss: 1.0857
# Epoch 29/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5704 - loss: 1.0737 - val_accuracy: 0.5761 - val_loss: 1.0776
# Epoch 30/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5722 - loss: 1.0764 - val_accuracy: 0.5761 - val_loss: 1.0711
# Epoch 31/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5765 - loss: 1.0666 - val_accuracy: 0.5868 - val_loss: 1.0622
# Epoch 32/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5820 - loss: 1.0544 - val_accuracy: 0.5832 - val_loss: 1.0557
# Epoch 33/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5789 - loss: 1.0642 - val_accuracy: 0.5895 - val_loss: 1.0468
# Epoch 34/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5968 - loss: 1.0410 - val_accuracy: 0.5886 - val_loss: 1.0397
# Epoch 35/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.5901 - loss: 1.0368 - val_accuracy: 0.5908 - val_loss: 1.0344
# Epoch 36/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6052 - loss: 1.0175 - val_accuracy: 0.5939 - val_loss: 1.0237
# Epoch 37/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6059 - loss: 1.0131 - val_accuracy: 0.5988 - val_loss: 1.0157
# Epoch 38/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6074 - loss: 1.0123 - val_accuracy: 0.6029 - val_loss: 1.0079
# Epoch 39/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6068 - loss: 1.0111 - val_accuracy: 0.6122 - val_loss: 1.0029
# Epoch 40/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6100 - loss: 1.0055 - val_accuracy: 0.6149 - val_loss: 0.9924
# Epoch 41/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6141 - loss: 0.9944 - val_accuracy: 0.6158 - val_loss: 0.9857
# Epoch 42/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6182 - loss: 0.9859 - val_accuracy: 0.6229 - val_loss: 0.9793
# Epoch 43/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6190 - loss: 0.9784 - val_accuracy: 0.6265 - val_loss: 0.9695
# Epoch 44/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6362 - loss: 0.9598 - val_accuracy: 0.6270 - val_loss: 0.9616
# Epoch 45/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6354 - loss: 0.9567 - val_accuracy: 0.6328 - val_loss: 0.9565
# Epoch 46/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6348 - loss: 0.9519 - val_accuracy: 0.6359 - val_loss: 0.9470
# Epoch 47/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6327 - loss: 0.9629 - val_accuracy: 0.6386 - val_loss: 0.9424
# Epoch 48/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6405 - loss: 0.9417 - val_accuracy: 0.6426 - val_loss: 0.9352
# Epoch 49/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6440 - loss: 0.9421 - val_accuracy: 0.6399 - val_loss: 0.9303
# Epoch 50/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6431 - loss: 0.9436 - val_accuracy: 0.6332 - val_loss: 0.9378
# Epoch 51/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6424 - loss: 0.9318 - val_accuracy: 0.6444 - val_loss: 0.9211
# Epoch 52/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6388 - loss: 0.9380 - val_accuracy: 0.6435 - val_loss: 0.9136
# Epoch 53/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6534 - loss: 0.9095 - val_accuracy: 0.6479 - val_loss: 0.9010
# Epoch 54/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6592 - loss: 0.9048 - val_accuracy: 0.6484 - val_loss: 0.8959
# Epoch 55/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6512 - loss: 0.9128 - val_accuracy: 0.6519 - val_loss: 0.8896
# Epoch 56/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6532 - loss: 0.9046 - val_accuracy: 0.6609 - val_loss: 0.8881
# Epoch 57/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6515 - loss: 0.9185 - val_accuracy: 0.6627 - val_loss: 0.8746
# Epoch 58/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6557 - loss: 0.9004 - val_accuracy: 0.6546 - val_loss: 0.8750
# Epoch 59/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6561 - loss: 0.8936 - val_accuracy: 0.6502 - val_loss: 0.8912
# Epoch 60/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6613 - loss: 0.8872 - val_accuracy: 0.6533 - val_loss: 0.8839
# Epoch 61/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6616 - loss: 0.8822 - val_accuracy: 0.6595 - val_loss: 0.8575
# Epoch 62/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6622 - loss: 0.8749 - val_accuracy: 0.6711 - val_loss: 0.8590
# Epoch 63/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6639 - loss: 0.8711 - val_accuracy: 0.6627 - val_loss: 0.8428
# Epoch 64/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6596 - loss: 0.8809 - val_accuracy: 0.6479 - val_loss: 0.8841
# Epoch 65/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6603 - loss: 0.8746 - val_accuracy: 0.6685 - val_loss: 0.8338
# Epoch 66/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6698 - loss: 0.8505 - val_accuracy: 0.6671 - val_loss: 0.8301
# Epoch 67/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6591 - loss: 0.8635 - val_accuracy: 0.6680 - val_loss: 0.8256
# Epoch 68/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6627 - loss: 0.8557 - val_accuracy: 0.6667 - val_loss: 0.8217
# Epoch 69/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6691 - loss: 0.8484 - val_accuracy: 0.6711 - val_loss: 0.8149
# Epoch 70/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6674 - loss: 0.8475 - val_accuracy: 0.6640 - val_loss: 0.8521
# Epoch 71/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6590 - loss: 0.8676 - val_accuracy: 0.6560 - val_loss: 0.8466
# Epoch 72/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6607 - loss: 0.8600 - val_accuracy: 0.6515 - val_loss: 0.8541
# Epoch 73/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6738 - loss: 0.8326 - val_accuracy: 0.6685 - val_loss: 0.8144
# Epoch 74/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6702 - loss: 0.8345 - val_accuracy: 0.6627 - val_loss: 0.8280
# Epoch 75/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6705 - loss: 0.8543 - val_accuracy: 0.6778 - val_loss: 0.8456
# Epoch 76/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6688 - loss: 0.8296 - val_accuracy: 0.6743 - val_loss: 0.8366
# Epoch 77/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6565 - loss: 0.8546 - val_accuracy: 0.6689 - val_loss: 0.8576
# Epoch 78/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6791 - loss: 0.8181 - val_accuracy: 0.6778 - val_loss: 0.7847
# Epoch 79/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6744 - loss: 0.8159 - val_accuracy: 0.6769 - val_loss: 0.7817
# Epoch 80/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6660 - loss: 0.8187 - val_accuracy: 0.6546 - val_loss: 0.8277

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Save the model
model.save('cnn_bilstm_kidney_classification.h5')
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6879 - loss: 0.7696
# Test Accuracy: 67.87%

# %%
# Evaluate the model on the test data
from sklearn.metrics import precision_score, recall_score, f1_score
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Predict on the test set
y_pred = model.predict(X_test, verbose=0)

# Convert predictions and true labels to categorical format
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted classes
y_true_classes = np.argmax(y_test, axis=1)  # True classes

# Calculate precision, recall, and F1-score
print("\nClassification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=classes))


# Calculate precision, recall, F1 score, and confusion matrix
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')


# Print the results
print(f"Precision: {precision:.4f}%")
print(f"Recall: {recall:.4f}%")
print(f"F1 Score: {f1:.4f}%")


conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.ylabel('True Labels')
plt.xlabel('Predicted Labels')
plt.show()
# Out:
# Test Accuracy: 67.87%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.67      0.94      0.78       526
#         Cyst       0.80      0.86      0.83       373
#        Tumor       0.29      0.13      0.18       236
#        Stone       0.00      0.00      0.00       110
#
#     accuracy                           0.68      1245
#    macro avg       0.44      0.48      0.45      1245
# weighted avg       0.58      0.68      0.61      1245
#
# Precision: 0.5757%
# Recall: 0.6787%
# F1 Score: 0.6117%
#
# Confusion Matrix:
# [[493  11  22   0]
#  [ 13 322  38   0]
#  [175  31  30   0]
#  [ 54  41  15   0]]
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
# Define class names
classes = ['Normal', 'Cyst', 'Tumor', 'Stone']


# Binarize the labels for multi-class (One-vs-Rest)
n_classes = y_test.shape[1]  # Assuming y_test is one-hot encoded
y_test_binarized = label_binarize(np.argmax(y_test, axis=1), classes=range(n_classes))
y_pred_probs = model.predict(X_test) 


# Compute ROC curve and AUC for each class
fpr = {}
tpr = {}
roc_auc = {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_binarized.ravel(), y_pred_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
colors = ['blue', 'green', 'red', 'purple']  # Add more colors if needed
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'{classes[i]} (AUC = {roc_auc[i]:.2f})')

# Plot micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], color='deeppink', linestyle=':', linewidth=4,
         label=f'Micro-average ROC (AUC = {roc_auc["micro"]:.2f})')

# Plot the diagonal line
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')

# Add plot labels and legend
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Multi-Class')
plt.legend(loc="lower right")
plt.show()
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# Load and preprocess the image
image_path = '/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/Cyst/Cyst- (1009).jpg'

# Load the image with target size same as the input size of the model
img = load_img(image_path, target_size=(img_size, img_size))
img_array = img_to_array(img)  # Convert to numpy array
img_array = img_array / 255.0  # Normalize the image (same as during training)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Predict the class of the image
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions[0])  # Get the index of the highest probability

# Map the predicted index to the class name
predicted_class_name = classes[predicted_class]

# Plot the image
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.axis('off')  # Hide the axis
plt.title(f"Predicted Class: {predicted_class_name}\nClass Probabilities: {predictions[0]}")
plt.show()

# Print the result
print(f"Predicted class: {predicted_class_name}")
print(f"Class probabilities: {predictions[0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted class: Cyst
# Class probabilities: [0.00909146 0.89027584 0.04112635 0.05950639]
