# %%
import os
import cv2
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Bidirectional, LSTM, GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Reshape
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import load_img, img_to_array
print("Done")
# Out:
# Done

# %%
# Dataset path and parameters
dataset_path = '/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone'
img_size = 150
batch_size = 64
classes = ['Normal', 'Cyst', 'Tumor', 'Stone']

# Load and preprocess the dataset
def load_data(dataset_path, classes):
    data = []
    labels = []
    for i, class_name in enumerate(classes):
        class_path = os.path.join(dataset_path, class_name)
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            try:
                img = cv2.imread(img_path)
                img = cv2.resize(img, (img_size, img_size))
                data.append(img)
                labels.append(i)
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")
    return np.array(data), np.array(labels)

data, labels = load_data(dataset_path, classes)

# %%
# Normalize and one-hot encode
data = data / 255.0
labels = to_categorical(labels, num_classes=len(classes))
#labels

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# CNN with BiLSTM model
input_layer = Input(shape=(img_size, img_size, 3))

# CNN Layers
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = GlobalAveragePooling2D()(x)  # Convert feature maps to 1D vector

# Reshape for BiLSTM
x = Reshape((1, -1))(x)  # Reshape to (batch_size, timesteps=1, features)

# BiLSTM Layer
x = Bidirectional(LSTM(128, return_sequences=False))(x)

# Fully Connected Layers
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output_layer = Dense(len(classes), activation='softmax')(x)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
from tensorflow.keras.optimizers import Adamax

model.compile(optimizer=Adamax(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=batch_size,
    epochs=80,
    verbose=1
)
# Out:
# Epoch 1/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 15s 67ms/step - accuracy: 0.4191 - loss: 1.2744 - val_accuracy: 0.5872 - val_loss: 1.0782
# Epoch 2/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.5946 - loss: 1.0285 - val_accuracy: 0.6113 - val_loss: 1.0092
# Epoch 3/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6337 - loss: 0.9596 - val_accuracy: 0.6506 - val_loss: 0.9198
# Epoch 4/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6541 - loss: 0.9198 - val_accuracy: 0.6720 - val_loss: 0.8706
# Epoch 5/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.6629 - loss: 0.8960 - val_accuracy: 0.6591 - val_loss: 0.8625
# Epoch 6/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.6885 - loss: 0.8560 - val_accuracy: 0.7015 - val_loss: 0.8147
# Epoch 7/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6825 - loss: 0.8482 - val_accuracy: 0.6613 - val_loss: 0.8521
# Epoch 8/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6854 - loss: 0.8365 - val_accuracy: 0.7033 - val_loss: 0.7924
# Epoch 9/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.6926 - loss: 0.8224 - val_accuracy: 0.7073 - val_loss: 0.7770
# Epoch 10/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.6984 - loss: 0.8081 - val_accuracy: 0.6983 - val_loss: 0.7758
# Epoch 11/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.6952 - loss: 0.8104 - val_accuracy: 0.7166 - val_loss: 0.7575
# Epoch 12/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7018 - loss: 0.7900 - val_accuracy: 0.6890 - val_loss: 0.8598
# Epoch 13/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7040 - loss: 0.7849 - val_accuracy: 0.6805 - val_loss: 0.8752
# Epoch 14/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7084 - loss: 0.7734 - val_accuracy: 0.7318 - val_loss: 0.7389
# Epoch 15/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.7089 - loss: 0.7650 - val_accuracy: 0.7229 - val_loss: 0.7206
# Epoch 16/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7222 - loss: 0.7401 - val_accuracy: 0.7363 - val_loss: 0.7360
# Epoch 17/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7210 - loss: 0.7333 - val_accuracy: 0.7470 - val_loss: 0.7007
# Epoch 18/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7313 - loss: 0.7161 - val_accuracy: 0.7323 - val_loss: 0.7468
# Epoch 19/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7377 - loss: 0.6802 - val_accuracy: 0.7367 - val_loss: 0.6806
# Epoch 20/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7348 - loss: 0.7027 - val_accuracy: 0.7515 - val_loss: 0.6414
# Epoch 21/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7466 - loss: 0.6651 - val_accuracy: 0.7287 - val_loss: 0.7118
# Epoch 22/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7550 - loss: 0.6476 - val_accuracy: 0.7680 - val_loss: 0.6014
# Epoch 23/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7591 - loss: 0.6267 - val_accuracy: 0.7510 - val_loss: 0.6240
# Epoch 24/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7688 - loss: 0.6163 - val_accuracy: 0.7778 - val_loss: 0.5723
# Epoch 25/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7643 - loss: 0.6044 - val_accuracy: 0.7680 - val_loss: 0.5949
# Epoch 26/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7772 - loss: 0.5660 - val_accuracy: 0.7867 - val_loss: 0.5321
# Epoch 27/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.7847 - loss: 0.5493 - val_accuracy: 0.7934 - val_loss: 0.5183
# Epoch 28/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7935 - loss: 0.5381 - val_accuracy: 0.8077 - val_loss: 0.5060
# Epoch 29/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7976 - loss: 0.5241 - val_accuracy: 0.7773 - val_loss: 0.5327
# Epoch 30/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8065 - loss: 0.5084 - val_accuracy: 0.8090 - val_loss: 0.4969
# Epoch 31/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7945 - loss: 0.5464 - val_accuracy: 0.7706 - val_loss: 0.6016
# Epoch 32/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.7903 - loss: 0.5527 - val_accuracy: 0.8304 - val_loss: 0.4909
# Epoch 33/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8023 - loss: 0.5125 - val_accuracy: 0.8170 - val_loss: 0.4690
# Epoch 34/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8116 - loss: 0.4871 - val_accuracy: 0.8309 - val_loss: 0.4628
# Epoch 35/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8187 - loss: 0.4688 - val_accuracy: 0.8483 - val_loss: 0.4131
# Epoch 36/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8104 - loss: 0.5114 - val_accuracy: 0.8434 - val_loss: 0.4207
# Epoch 37/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.8241 - loss: 0.4604 - val_accuracy: 0.8456 - val_loss: 0.4245
# Epoch 38/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8277 - loss: 0.4541 - val_accuracy: 0.7979 - val_loss: 0.5087
# Epoch 39/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8275 - loss: 0.4345 - val_accuracy: 0.8148 - val_loss: 0.4774
# Epoch 40/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8361 - loss: 0.4429 - val_accuracy: 0.8648 - val_loss: 0.3680
# Epoch 41/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8394 - loss: 0.4250 - val_accuracy: 0.8545 - val_loss: 0.3826
# Epoch 42/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8481 - loss: 0.4116 - val_accuracy: 0.8001 - val_loss: 0.4992
# Epoch 43/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8371 - loss: 0.4257 - val_accuracy: 0.8594 - val_loss: 0.3778
# Epoch 44/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8544 - loss: 0.4042 - val_accuracy: 0.8514 - val_loss: 0.3951
# Epoch 45/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8547 - loss: 0.3825 - val_accuracy: 0.8327 - val_loss: 0.4337
# Epoch 46/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8484 - loss: 0.3920 - val_accuracy: 0.8635 - val_loss: 0.3487
# Epoch 47/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8559 - loss: 0.3768 - val_accuracy: 0.8675 - val_loss: 0.3278
# Epoch 48/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8539 - loss: 0.3743 - val_accuracy: 0.8666 - val_loss: 0.3390
# Epoch 49/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8547 - loss: 0.3815 - val_accuracy: 0.8679 - val_loss: 0.3440
# Epoch 50/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8683 - loss: 0.3493 - val_accuracy: 0.8603 - val_loss: 0.3689
# Epoch 51/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8534 - loss: 0.3755 - val_accuracy: 0.8456 - val_loss: 0.3785
# Epoch 52/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8712 - loss: 0.3421 - val_accuracy: 0.8701 - val_loss: 0.3183
# Epoch 53/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8656 - loss: 0.3431 - val_accuracy: 0.8804 - val_loss: 0.3061
# Epoch 54/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8743 - loss: 0.3299 - val_accuracy: 0.8701 - val_loss: 0.3235
# Epoch 55/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8724 - loss: 0.3351 - val_accuracy: 0.8782 - val_loss: 0.2964
# Epoch 56/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8752 - loss: 0.3161 - val_accuracy: 0.8782 - val_loss: 0.3165
# Epoch 57/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8832 - loss: 0.3025 - val_accuracy: 0.8938 - val_loss: 0.2829
# Epoch 58/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8861 - loss: 0.3047 - val_accuracy: 0.8934 - val_loss: 0.2693
# Epoch 59/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8889 - loss: 0.2993 - val_accuracy: 0.8929 - val_loss: 0.2759
# Epoch 60/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8916 - loss: 0.2896 - val_accuracy: 0.8911 - val_loss: 0.2771
# Epoch 61/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8894 - loss: 0.2957 - val_accuracy: 0.8724 - val_loss: 0.3171
# Epoch 62/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8926 - loss: 0.2884 - val_accuracy: 0.8733 - val_loss: 0.3234
# Epoch 63/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9020 - loss: 0.2590 - val_accuracy: 0.8376 - val_loss: 0.4158
# Epoch 64/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8815 - loss: 0.3046 - val_accuracy: 0.8947 - val_loss: 0.2690
# Epoch 65/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8915 - loss: 0.2783 - val_accuracy: 0.9036 - val_loss: 0.2575
# Epoch 66/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9049 - loss: 0.2507 - val_accuracy: 0.9045 - val_loss: 0.2347
# Epoch 67/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9037 - loss: 0.2493 - val_accuracy: 0.9032 - val_loss: 0.2368
# Epoch 68/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9003 - loss: 0.2520 - val_accuracy: 0.9054 - val_loss: 0.2395
# Epoch 69/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9103 - loss: 0.2378 - val_accuracy: 0.8675 - val_loss: 0.3497
# Epoch 70/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8886 - loss: 0.2860 - val_accuracy: 0.9072 - val_loss: 0.2098
# Epoch 71/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8970 - loss: 0.2697 - val_accuracy: 0.8371 - val_loss: 0.4313
# Epoch 72/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.8895 - loss: 0.2783 - val_accuracy: 0.9090 - val_loss: 0.2167
# Epoch 73/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.9100 - loss: 0.2403 - val_accuracy: 0.9076 - val_loss: 0.2158
# Epoch 74/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9119 - loss: 0.2304 - val_accuracy: 0.9116 - val_loss: 0.2223
# Epoch 75/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9152 - loss: 0.2212 - val_accuracy: 0.9174 - val_loss: 0.1998
# Epoch 76/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9212 - loss: 0.2080 - val_accuracy: 0.8621 - val_loss: 0.3467
# Epoch 77/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9134 - loss: 0.2254 - val_accuracy: 0.9206 - val_loss: 0.1974
# Epoch 78/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9150 - loss: 0.2174 - val_accuracy: 0.9094 - val_loss: 0.2272
# Epoch 79/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9154 - loss: 0.2153 - val_accuracy: 0.9273 - val_loss: 0.1922
# Epoch 80/80
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9119 - loss: 0.2259 - val_accuracy: 0.9331 - val_loss: 0.1863

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Save the model
model.save('cnn_bilstm_kidney_classification.h5')
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9476 - loss: 0.1629
# Test Accuracy: 94.46%

# %%
# Evaluate the model on the test data
from sklearn.metrics import precision_score, recall_score, f1_score
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Predict on the test set
y_pred = model.predict(X_test, verbose=0)

# Convert predictions and true labels to categorical format
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted classes
y_true_classes = np.argmax(y_test, axis=1)  # True classes

# Calculate precision, recall, and F1-score
print("\nClassification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=classes))


# Calculate precision, recall, F1 score, and confusion matrix
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')


# Print the results
print(f"Precision: {precision:.4f}%")
print(f"Recall: {recall:.4f}%")
print(f"F1 Score: {f1:.4f}%")


conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.ylabel('True Labels')
plt.xlabel('Predicted Labels')
plt.show()
# Out:
# Test Accuracy: 94.46%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.98      0.97       526
#         Cyst       0.93      0.98      0.95       373
#        Tumor       0.99      0.88      0.93       236
#        Stone       0.81      0.80      0.81       110
#
#     accuracy                           0.94      1245
#    macro avg       0.92      0.91      0.92      1245
# weighted avg       0.95      0.94      0.94      1245
#
# Precision: 0.9455%
# Recall: 0.9446%
# F1 Score: 0.9441%
#
# Confusion Matrix:
# [[516   0   2   8]
#  [  0 365   0   8]
#  [ 13  12 207   4]
#  [  6  16   0  88]]

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
# Define class names
classes = ['Normal', 'Cyst', 'Tumor', 'Stone']


# Binarize the labels for multi-class (One-vs-Rest)
n_classes = y_test.shape[1]  # Assuming y_test is one-hot encoded
y_test_binarized = label_binarize(np.argmax(y_test, axis=1), classes=range(n_classes))
y_pred_probs = model.predict(X_test) 


# Compute ROC curve and AUC for each class
fpr = {}
tpr = {}
roc_auc = {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_binarized.ravel(), y_pred_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
colors = ['blue', 'green', 'red', 'purple']  # Add more colors if needed
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'{classes[i]} (AUC = {roc_auc[i]:.2f})')

# Plot micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], color='deeppink', linestyle=':', linewidth=4,
         label=f'Micro-average ROC (AUC = {roc_auc["micro"]:.2f})')

# Plot the diagonal line
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')

# Add plot labels and legend
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Multi-Class')
plt.legend(loc="lower right")
plt.show()
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
# Load and preprocess the image
image_path = '/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/Cyst/Cyst- (1009).jpg'

# Load the image with target size same as the input size of the model
img = load_img(image_path, target_size=(img_size, img_size))
img_array = img_to_array(img)  # Convert to numpy array
img_array = img_array / 255.0  # Normalize the image (same as during training)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Predict the class of the image
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions[0])  # Get the index of the highest probability

# Map the predicted index to the class name
predicted_class_name = classes[predicted_class]

# Plot the image
plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.axis('off')  # Hide the axis
plt.title(f"Predicted Class: {predicted_class_name}\nClass Probabilities: {predictions[0]}")
plt.show()

# Print the result
print(f"Predicted class: {predicted_class_name}")
print(f"Class probabilities: {predictions[0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted class: Cyst
# Class probabilities: [6.1658923e-08 9.9831957e-01 1.6583379e-03 2.1933622e-05]
